# %% [markdown]
# ### Machine Learning Algorithm Validation and comparison powered by AutoML

# %%
#!pip install -q -U git+https://github.com/mljar/mljar-supervised.git@master

# %%
from supervised.automl import AutoML # mljar-supervised
from sklearn.model_selection import train_test_split

import pandas as pd

# %%
df = pd.read_csv(r'/content/data.csv')

# %%
df.drop(['Unnamed: 0', 'duration_ms', 'song_title', 'artist'] ,  axis = 1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df[df.columns[:-1]], df["target"], test_size=0.25)

# %%
# Initialize AutoML in Explain Mode
automl = AutoML(mode="Perform")
automl.fit(X_train, y_train)
# Out:
# AutoML directory: AutoML_3
# The task is binary_classification with evaluation metric logloss
# AutoML will use algorithms: ['Linear', 'Random Forest', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# * Step simple_algorithms will try to check up to 1 model
# 1_Linear logloss 0.637437 trained in 81.9 seconds (1-sample predict time 0.532 seconds)
# * Step default_algorithms will try to check up to 5 models
# 2_Default_LightGBM logloss 0.500815 trained in 21.14 seconds (1-sample predict time 0.2706 seconds)
# 3_Default_Xgboost logloss 0.494666 trained in 20.8 seconds (1-sample predict time 0.1962 seconds)
# 4_Default_CatBoost logloss 0.47571 trained in 31.14 seconds (1-sample predict time 0.2593 seconds)
# ...

# %%
display(df['target'] == 1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2012    False
# 2013    False
# 2014    False
# 2015    False
# 2016    False
# Name: target, Length: 2017, dtype: bool

# %%
hist = df.hist(figsize=(10,10),column='target')
